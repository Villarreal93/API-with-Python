# %%
import requests
import pandas as pd
import time

# %%
API_key = "AIzaSyDN7tMKovdA79x7ixd4tk7pAD_HmOATJdA"
Channel_ID = "UCDVYQ4Zhbm3S2dlz7P1GBDg" #NFL's channel id

# %%
#make API call for general information
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_key+"&channelId="+Channel_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'bK_uiqT7SHa8nYlLUeWdYSGmPEY',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'PL',
#  'pageInfo': {'totalResults': 26190, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'HAkMx4-pkwXs7p6UAxlcEA9U0Ws',
#    'id': {'kind': 'youtube#video', 'videoId': 'Zn2ZDUFdRmA'},
#    'snippet': {'publishedAt': '2021-11-26T23:59:13Z',
#     'channelId': 'UCDVYQ4Zhbm3S2dlz7P1GBDg',
#     'title': 'Week 12 Game Picks! | GameDay View',
#     'description': '0:00 Intro 1:43 Rams-Packers 5:14 Vikings-49ers 9:05 Titans-Patriots 13:38 Proper Performances 22:25 Browns-Ravens 25:56 Steelers-Bengals 29:39 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zn2ZDUFdRmA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Zn2ZDUFdRmA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
#latest video published by NFL channel
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'HAkMx4-pkwXs7p6UAxlcEA9U0Ws',
#  'id': {'kind': 'youtube#video', 'videoId': 'Zn2ZDUFdRmA'},
#  'snippet': {'publishedAt': '2021-11-26T23:59:13Z',
#   'channelId': 'UCDVYQ4Zhbm3S2dlz7P1GBDg',
#   'title': 'Week 12 Game Picks! | GameDay View',
#   'description': '0:00 Intro 1:43 Rams-Packers 5:14 Vikings-49ers 9:05 Titans-Patriots 13:38 Proper Performances 22:25 Browns-Ravens 25:56 Steelers-Bengals 29:39 ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zn2ZDUFdRmA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Zn2ZDUFdRmA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Zn2ZDUFdRmA/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'NFL',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-11-26T23:59:13Z'}}

# %%
#Command to extract video id
response['items'][0]['id']['videoId']
# Out:
# 'Zn2ZDUFdRmA'

# %%
video_id = response['items'][0]['id']['videoId']
video_title = response['items'][0]['snippet']['title']
video_title = str(video_title).replace("&amp;","") #just to avoid & on titles

# %%
video_title
# Out:
# 'Week 12 Game Picks! | GameDay View'

# %%
upload_date = response['items'][0]['snippet']['publishedAt']
upload_date
# Out:
# '2021-11-26T23:59:13Z'

# %%
#getting rid of time
upload_date = str(upload_date).split("T")[0]
upload_date
# Out:
# '2021-11-26'

# %%
#Loop to iterate over all videos
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;","")
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0]
        
        print(video_id)
        print(video_title)
        print(upload_date)
# Out:
# Zn2ZDUFdRmA
# Week 12 Game Picks! | GameDay View
# 2021-11-26
# fP9kNVJpNuQ
# Week 12 Preview for EVERY Game | Around the NFL
# 2021-11-26
# xD4lNNLvrdk
# Week 12 NFL Game Picks  Win Probability | NFL 2021
# 2021-11-26
# 4XVXl3R2m7c
# Cam Jordan  Crescent City Corps Bringing Change to Police, Community in New Orleans
# 2021-11-26
# dytzX391nFQ
# Say Their Stories: Eddie Jackson Aids and Inspires At-Risk-Youth through Remain to Reach Foundation
# 2021-11-26
# O6-na2b4RYU
# Bills vs. Saints Week 12 Highlights | NFL 2021
# 2021-11-26
# PJYRi1e2xDM
# Knox is Feasting on Touchdowns Tonight!
# 2021-11-26
# IHWV19-UC1E
# Saints Defense Has Room for Seconds!
# 2021-11-26
# L1xhFfxsCWk
# When it&#39;s Turkey Bowl  Your Buddy Swears He&#39;s on the Same Page as You
# 2021-11-26
# h5e-V338GLo
# Every Hunter Renfrow Catch from 134-Yd Game vs. Cowboys | NFL 2021 Highlights
# 2021-11-26
# CSNIC-Esimo
# Raiders vs. Cowboys CRAZY ENDING Thanksgiving Day Thriller
# 2021-11-26
# VJuimaPPFDo
# ...

# %%
#API for video statistics
url_stats = "https://www.googleapis.com/youtube/v3/videos?part=statistics&id="+video_id+"&key="+API_key
response_stats = requests.get(url_stats).json()

# %%
response_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'zKqK9UJbwMxvLQNAB-EdLMVwgoY',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'CfrwTsmcHZNeOc4sGuzFsg319u0',
#    'id': '8vLH1jtGZcc',
#    'statistics': {'viewCount': '64041',
#     'likeCount': '1476',
#     'dislikeCount': '39',
#     'favoriteCount': '0',
#     'commentCount': '31'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
response_stats['items'][0]['statistics']['likeCount']
# Out:
# '1476'

# %%
view_count = response_stats['items'][0]['statistics']['viewCount']
like_count = response_stats['items'][0]['statistics']['likeCount']
dislike_count = response_stats['items'][0]['statistics']['dislikeCount']
comment_count = response_stats['items'][0]['statistics']['commentCount']

# %%
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;","")
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0]
        
        url_stats = "https://www.googleapis.com/youtube/v3/videos?part=statistics&id="+video_id+"&key="+API_key
        response_stats = requests.get(url_stats).json()
        
        view_count = response_stats['items'][0]['statistics']['viewCount']
        like_count = response_stats['items'][0]['statistics']['likeCount']
        dislike_count = response_stats['items'][0]['statistics']['dislikeCount']
        comment_count = response_stats['items'][0]['statistics']['commentCount']
        
        print(video_id)
        print(video_title)
        print(upload_date)
        print("View Count: "+view_count)
        print("Likes: "+like_count)
        print("Dislikes: "+dislike_count)
        print("# Comments: "+comment_count)
# Out:
# Zn2ZDUFdRmA
# Week 12 Game Picks! | GameDay View
# 2021-11-26
# View Count: 52355
# Likes: 1099
# Dislikes: 54
# # Comments: 153
# fP9kNVJpNuQ
# Week 12 Preview for EVERY Game | Around the NFL
# 2021-11-26
# View Count: 34093
# Likes: 660
# Dislikes: 38
# # Comments: 43
# xD4lNNLvrdk
# Week 12 NFL Game Picks  Win Probability | NFL 2021
# 2021-11-26
# View Count: 44867
# Likes: 1148
# Dislikes: 54
# # Comments: 284
# 4XVXl3R2m7c
# Cam Jordan  Crescent City Corps Bringing Change to Police, Community in New Orleans
# 2021-11-26
# View Count: 3436
# Likes: 83
# Dislikes: 29
# # Comments: 28
# dytzX391nFQ
# Say Their Stories: Eddie Jackson Aids and Inspires At-Risk-Youth through Remain to Reach Foundation
# 2021-11-26
# View Count: 4268
# Likes: 134
# Dislikes: 17
# # Comments: 43
# O6-na2b4RYU
# Bills vs. Saints Week 12 Highlights | NFL 2021
# 2021-11-26
# View Count: 1113044
# Likes: 10798
# Dislikes: 366
# # Comments: 1692
# PJYRi1e2xDM
# Knox is Feasting on Touchdowns Tonight!
# ...

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","dislike_count","comment_count"])
df
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, upload_date, view_count, like_count, dislike_count, comment_count]
# Index: []

# %%
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;","")
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0]
        
        url_stats = "https://www.googleapis.com/youtube/v3/videos?part=statistics&id="+video_id+"&key="+API_key
        response_stats = requests.get(url_stats).json()
        
        view_count = response_stats['items'][0]['statistics']['viewCount']
        like_count = response_stats['items'][0]['statistics']['likeCount']
        dislike_count = response_stats['items'][0]['statistics']['dislikeCount']
        comment_count = response_stats['items'][0]['statistics']['commentCount']

        #saving data to a pandas df
        df = df.append({'video_id': video_id,'video_title':video_title,
                'upload_date':upload_date,'view_count':view_count,
                'like_count':like_count,'dislike_count':dislike_count,
                'comment_count':comment_count}, ignore_index=True)

# %%
df.head(5)
# Out:
#       video_id                                        video_title upload_date  \
# 0  Zn2ZDUFdRmA                 Week 12 Game Picks! | GameDay View  2021-11-26
# 1  fP9kNVJpNuQ    Week 12 Preview for EVERY Game | Around the NFL  2021-11-26
# 2  xD4lNNLvrdk  Week 12 NFL Game Picks  Win Probability | NFL ...  2021-11-26
# 3  4XVXl3R2m7c  Cam Jordan  Crescent City Corps Bringing Chang...  2021-11-26
# 4  dytzX391nFQ  Say Their Stories: Eddie Jackson Aids and Insp...  2021-11-26
#
#   view_count like_count dislike_count comment_count
# 0      52355       1099            54           153
# 1      34093        660            38            43
# 2      44867       1148            54           284
# 3       3434         83            29            28
# 4       4268        134            17            43

# %%
#using functions to make the code more efficient
def get_video_details(video_id):
    url_stats = "https://www.googleapis.com/youtube/v3/videos?part=statistics&id="+video_id+"&key="+API_key
    response_stats = requests.get(url_stats).json()
        
    view_count = response_stats['items'][0]['statistics']['viewCount']
    like_count = response_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_stats['items'][0]['statistics']['dislikeCount']
    comment_count = response_stats['items'][0]['statistics']['commentCount']
        
    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos(df):
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+API_key+"&channelId="+Channel_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken
    response = requests.get(url).json()
    
    time.sleep(1) #command to make sure API data is received before jumping in the for loop
    
    for video in response['items']:
        if video['id']['kind'] == "youtube#video":
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            video_title = str(video_title).replace("&amp;","")
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]
            
            view_count, like_count, dislike_count, comment_count = get_video_details(video_id)
        
            df = df.append({'video_id': video_id,'video_title':video_title,
                    'upload_date':upload_date,'view_count':view_count,
                    'like_count':like_count,'dislike_count':dislike_count,
                    'comment_count':comment_count}, ignore_index=True)    
    
    return df

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","dislike_count","comment_count"])

df = get_videos(df)

# %%
df.head(5)
# Out:
#       video_id                                        video_title upload_date  \
# 0  Zn2ZDUFdRmA                 Week 12 Game Picks! | GameDay View  2021-11-26
# 1  fP9kNVJpNuQ    Week 12 Preview for EVERY Game | Around the NFL  2021-11-26
# 2  xD4lNNLvrdk  Week 12 NFL Game Picks  Win Probability | NFL ...  2021-11-26
# 3  4XVXl3R2m7c  Cam Jordan  Crescent City Corps Bringing Chang...  2021-11-26
# 4  dytzX391nFQ  Say Their Stories: Eddie Jackson Aids and Insp...  2021-11-26
#
#   view_count like_count dislike_count comment_count
# 0      52558       1099            54           154
# 1      34160        660            39            43
# 2      44984       1148            55           284
# 3       3434         83            29            28
# 4       4268        134            17            43
